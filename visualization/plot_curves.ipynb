# %%
import matplotlib.pyplot as plt

# %%
def plot_curves(maturity , base , shocked):
    plt.plot( maturity , base  , label = 'Base Curve' )
    plt.plot( maturity , shocked  , label = 'Shocked Curve' )
    plt.legend()
    plt.grid()
    plt.show()
